# %%
from scipy.misc import imread, imresize, imsave
import numpy as np
import image_utils as iu
import matplotlib.pyplot as plt
from PIL import Image
import h5py
import time
# Out:
# /home/wgy/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
dataset = iu.Dataset(image_dir='./test_image/', color_mode='F',slice_mode='normal', threshold=50, scale=4, stride=24, lr_size='same', save_path='./test.h5')

# %%
dataset.channel
# Out:
# 1

# %%
imgen = dataset.image_flow_from_h5(big_batch_size=500)

# %%
a = time.time()
for i in range(100):
    data, label = next(imgen)
print(data.shape, label.shape)
for i, img in enumerate(label):
    plt.subplot(4, 4, 1+i)
    plt.imshow(img.squeeze())
plt.show()
b = time.time()
print(b-a, 's')
# Out:
# (16, 48, 48, 1) (16, 48, 48, 1)
# 0.7088093757629395 s

# %%
import os

# %%
os.path.abspath('./data/car/')
# Out:
# '/home/wgy/AnacondaProjects/SR/data/car'
