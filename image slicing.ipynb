# %%
import numpy as np
from scipy.misc import imresize, imread

# %%
import image_utils as iu
import matplotlib.pyplot as plt
# Out:
# /home/wgy/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
filepath = './test_image/Spidy.jpg'
image = imread(filepath, mode='F')
plt.imshow(image)
plt.show()
print(image.shape)
# Out:
# /home/wgy/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# (412, 550)

# %% [markdown]
# ## Slice normally

# %%
N, data, size_m = iu.im_slice(image, size=48, stride=24)
print(N, data.shape)
# Out:
# 336 (336, 48, 48, 1)

# %%
for i, img in enumerate(data):
    plt.subplot(10, 10, 1+i)
    plt.imshow(img.squeeze())
    if i >= 99:
        break
plt.show()

# %%
plt.imshow(data[63].squeeze())
plt.show()

# %%
## Merging to original image :

# %%
image_orig = iu.merge_to_original(data, size_m, stride=24)

# %%
print(image_orig.shape)
# Out:
# (408, 528)

# %%
plt.imshow((image_orig))
plt.show()

# %% [markdown]
# ## Slice randomly

# %%
N, data,_ = iu.im_slice(image, size=48, stride=24, num=100, seed=0, mode='random')
print(N, data.shape)
# Out:
# 100 (100, 48, 48, 1)

# %%
for i, img in enumerate(data):
    plt.subplot(10, 10, 1+i)
    plt.imshow(img.squeeze())
    if i >= 99:
        break
plt.show()

# %% [markdown]
# ## Slice with Removing-Redundance

# %%
N, data,_ = iu.im_slice(image, size=48, stride=24, threshold=70, mode='rm_redundancy')
print(N, data.shape)
# Out:
# 37 (37, 48, 48, 1)

# %%
for i, img in enumerate(data):
    plt.subplot(10, 10, 1+i)
    plt.imshow(img.squeeze())
    if i >= 99:
        break
plt.show()
